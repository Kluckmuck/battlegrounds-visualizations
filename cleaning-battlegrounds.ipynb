# %%
import pandas as pd
from pathlib import Path
#from dotenv import load_dotenv
import os
#load_dotenv()

## Create .env with folder var, like 'bg-viz/data/'
folder = os.getenv('FOLDER')
folder = "data/"

#df = pd.read_csv(folder + "BGMatchDataGames.csv")
df = pd.read_csv(folder+"BGMatchDataGames.csv")

df.dtypes
# Out:
# Date & Time                            object
# Hero                                   object
# Position                                int64
# MMR                                     int64
# Ending Minions                         object
# Minion Types                           object
# Turns taken to reach tavern tier 2      int64
# 3                                       int64
# 4                                       int64
# 5                                     float64
# 6                                     float64
# Ending Turn                             int64
# Game ID                                object
# Player                                 object
# dtype: object

# %%
#df
# Out:
# 'C:\\Users\\ELD\\bg-viz'

# %%
pos_avg = df['Position'].mean()
count = df['Game ID'].count()
print("Average Position; " + str(pos_avg))
print("Games Played; " + str(count))
# Out:
# Average Position; 4.0
# Games Played; 4

# %%
df = pd.read_csv(folder + "BGMatchDataBoards.csv")
df.dtypes
# Out:
# dateTime        object
# hero            object
# minions         object
# turn             int64
# isSelf          object
# combatResult    object
# gameId          object
# player          object
# dtype: object

# %%
## Creating separate features for each minion
df2 = df['minions'].str.split(r'[)][,]',expand=True)
df2 = df2.rename(columns={0:"minion1", 1:"minion2", 2:"minion3", 3:"minion4", 4:"minion5", 5:"minion6", 6:"minion7"})
df = df.merge(df2, left_index=True,right_index=True)
df = df.drop(['minions'], axis=1)

df
# Out:
#                           dateTime                   hero  turn isSelf  \
# 0    Mon, 19 Jul 2021 22:58:40 GMT          The Lich King     1    NaN
# 1    Mon, 19 Jul 2021 22:58:40 GMT       Captain Hooktusk     1    Yes
# 2    Mon, 19 Jul 2021 22:59:32 GMT  Trade Prince Gallywix     2    NaN
# 3    Mon, 19 Jul 2021 22:59:32 GMT       Captain Hooktusk     2    Yes
# 4    Mon, 19 Jul 2021 23:00:36 GMT              Chenvaala     3    NaN
# ..                             ...                    ...   ...    ...
# 389  Wed, 21 Jul 2021 01:43:00 GMT              Galakrond     8    Yes
# 390  Wed, 21 Jul 2021 01:45:11 GMT                 N'Zoth     9    NaN
# 391  Wed, 21 Jul 2021 01:45:11 GMT              Galakrond     9    Yes
# 392  Wed, 21 Jul 2021 01:47:28 GMT      Forest Warden Omu    10    NaN
# 393  Wed, 21 Jul 2021 01:47:28 GMT              Galakrond    10    Yes
#
#     combatResult                                gameId          player  \
# 0           Draw  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# 1           Draw  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# 2           Lose  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# 3            Win  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# 4           Lose  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# ..           ...                                   ...             ...
# 389         Lose  d00e3b88-c44e-45a3-802b-0bcc9ba010c4  Kluckmuck#1143
# 390         Lose  d00e3b88-c44e-45a3-802b-0bcc9ba010c4  Kluckmuck#1143
# 391          Win  d00e3b88-c44e-45a3-802b-0bcc9ba010c4  Kluckmuck#1143
# 392          Win  d00e3b88-c44e-45a3-802b-0bcc9ba010c4  Kluckmuck#1143
# 393         Lose  d00e3b88-c44e-45a3-802b-0bcc9ba010c4  Kluckmuck#1143
#
#                          minion1  \
# 0              Sellemental (2/2)
# 1              Murloc Scout (1/1
# 2              Sellemental (2/2)
# 3               Sellemental (2/2
# 4        Refreshing Anomaly (2/5
# ..                           ...
# 389     Murloc Tidehunter (15/14
# 390  Kaboom Bot (2/2 Deathrattle
# 391      Lightfang Enforcer (2/2
# 392    Wildfire Elemental (19/13
# 393  Deadly Spore (1/1 Poisonous
#
#                                              minion2  \
# 0                                               None
# 1                                  Sellemental (2/2)
# 2                                               None
# 3                                 Murloc Scout (1/1)
# 4                               Party Elemental (3/2
# ..                                               ...
# 389                               Sellemental (14/14
# 390                   Tormented Ritualist (2/3 Taunt
# 391                         Murloc Tidehunter (19/18
# 392   Crackling Cyclone (6/3 Divine Shield, Windfury
# 393                         Murloc Tidehunter (21/20
#
#                              minion3  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                Water Droplet (2/2)
# ..                               ...
# 389             Micro Machine (17/14
# 390   Infested Wolf (3/3 Deathrattle
# 391               Sellemental (18/18
# 392                    Lil' Rag (7/7
# 393               Sellemental (20/20
#
#                                              minion4  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ..                                               ...
# 389                          Lightfang Enforcer (2/2
# 390   Crackling Cyclone (4/1 Divine Shield, Windfury
# 391                             Micro Machine (22/18
# 392            Gentle Djinni (4/5 Taunt, Deathrattle
# 393                             Micro Machine (25/20
#
#                                     minion5                       minion6  \
# 0                                      None                          None
# 1                                      None                          None
# 2                                      None                          None
# 3                                      None                          None
# 4                                      None                          None
# ..                                      ...                           ...
# 389                  Brann Bronzebeard (2/4       Brann Bronzebeard (2/4)
# 390                     Micro Machine (1/2)                          None
# 391                  Brann Bronzebeard (2/4        Brann Bronzebeard (2/4
# 392   Gentle Djinni (7/8 Taunt, Deathrattle   Lieutenant Garr (9/44 Taunt
# 393                 Lightfang Enforcer (2/2        Brann Bronzebeard (2/4
#
#                            minion7
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ..                             ...
# 389                           None
# 390                           None
# 391   Deadly Spore (1/1 Poisonous)
# 392      Molten Rock (24/66 Taunt)
# 393        Brann Bronzebeard (2/4)
#
# [394 rows x 14 columns]

# %%
count = len(df.index)
print("Turns Played; " + str(count))
# Out:
# Turns Played; 394

# %%
#df2 = df[7:13].str.split('(',expand=True)
#df2.str.split('(',expand=True)
test = df2

for column in df2.columns:
    #print(df[column.])
    colName = column + '_stats'
    tmp[[column,colName]] = df2[column].str.split('(', expand=True)
    #tmp = tmp.rename(columns={1: column + '_stats'})
    break
    
    test = test.merge(tmp[1],left_index=True,right_index=True)
    
    #print(column)

# %%
tmp
# Out:
#                        0                1                 test  \
# 0           Sellemental              2/2)                 None
# 1          Murloc Scout               1/1                 None
# 2           Sellemental              2/2)                 None
# 3           Sellemental               2/2                 None
# 4    Refreshing Anomaly               2/5                 None
# ..                   ...              ...                  ...
# 389   Murloc Tidehunter             15/14                 None
# 390          Kaboom Bot   2/2 Deathrattle                 None
# 391  Lightfang Enforcer               2/2        Deadly Spore
# 392  Wildfire Elemental             19/13         Molten Rock
# 393        Deadly Spore     1/1 Poisonous   Brann Bronzebeard
#
#               test2              minion1                minion2  \
# 0              None         Sellemental                    None
# 1              None        Murloc Scout            Sellemental
# 2              None         Sellemental                    None
# 3              None         Sellemental           Murloc Scout
# 4              None  Refreshing Anomaly        Party Elemental
# ..              ...                  ...                    ...
# 389            None   Murloc Tidehunter            Sellemental
# 390            None          Kaboom Bot    Tormented Ritualist
# 391  1/1 Poisonous)  Lightfang Enforcer      Murloc Tidehunter
# 392    24/66 Taunt)  Wildfire Elemental      Crackling Cyclone
# 393            2/4)        Deadly Spore      Murloc Tidehunter
#
#              minion3               minion4               minion5  \
# 0               None                  None                  None
# 1               None                  None                  None
# 2               None                  None                  None
# 3               None                  None                  None
# 4     Water Droplet                   None                  None
# ..               ...                   ...                   ...
# 389   Micro Machine    Lightfang Enforcer     Brann Bronzebeard
# 390   Infested Wolf     Crackling Cyclone         Micro Machine
# 391     Sellemental         Micro Machine     Brann Bronzebeard
# 392        Lil' Rag         Gentle Djinni         Gentle Djinni
# 393     Sellemental         Micro Machine    Lightfang Enforcer
#
#                  minion6  ...            minion5stats minion6stats  \
# 0                   None  ...                    None         None
# 1                   None  ...                    None         None
# 2                   None  ...                    None         None
# 3                   None  ...                    None         None
# 4                   None  ...                    None         None
# ..                   ...  ...                     ...          ...
# 389   Brann Bronzebeard   ...                     2/4         2/4)
# 390                 None  ...                    1/2)         None
# 391   Brann Bronzebeard   ...                     2/4          2/4
# 392     Lieutenant Garr   ...  7/8 Taunt, Deathrattle   9/44 Taunt
# 393   Brann Bronzebeard   ...                     2/2          2/4
#
#        minion7stats    minion1_stats                minion2_stats  \
# 0              None             2/2)                         None
# 1              None              1/1                         2/2)
# 2              None             2/2)                         None
# 3              None              2/2                         1/1)
# 4              None              2/5                          3/2
# ..              ...              ...                          ...
# 389            None            15/14                        14/14
# 390            None  2/2 Deathrattle                    2/3 Taunt
# 391  1/1 Poisonous)              2/2                        19/18
# 392    24/66 Taunt)            19/13  6/3 Divine Shield, Windfury
# 393            2/4)    1/1 Poisonous                        21/20
#
#        minion3_stats                minion4_stats           minion5_stats  \
# 0               None                         None                    None
# 1               None                         None                    None
# 2               None                         None                    None
# 3               None                         None                    None
# 4               2/2)                         None                    None
# ..               ...                          ...                     ...
# 389            17/14                          2/2                     2/4
# 390  3/3 Deathrattle  4/1 Divine Shield, Windfury                    1/2)
# 391            18/18                        22/18                     2/4
# 392              7/7       4/5 Taunt, Deathrattle  7/8 Taunt, Deathrattle
# 393            20/20                        25/20                     2/2
#
#     minion6_stats   minion7_stats
# 0            None            None
# 1            None            None
# 2            None            None
# 3            None            None
# 4            None            None
# ..            ...             ...
# 389          2/4)            None
# 390          None            None
# 391           2/4  1/1 Poisonous)
# 392    9/44 Taunt    24/66 Taunt)
# 393           2/4            2/4)
#
# [394 rows x 25 columns]

# %%
df2
# Out:
#                          minion1  \
# 0              Sellemental (2/2)
# 1              Murloc Scout (1/1
# 2              Sellemental (2/2)
# 3               Sellemental (2/2
# 4        Refreshing Anomaly (2/5
# ..                           ...
# 389     Murloc Tidehunter (15/14
# 390  Kaboom Bot (2/2 Deathrattle
# 391      Lightfang Enforcer (2/2
# 392    Wildfire Elemental (19/13
# 393  Deadly Spore (1/1 Poisonous
#
#                                              minion2  \
# 0                                               None
# 1                                  Sellemental (2/2)
# 2                                               None
# 3                                 Murloc Scout (1/1)
# 4                               Party Elemental (3/2
# ..                                               ...
# 389                               Sellemental (14/14
# 390                   Tormented Ritualist (2/3 Taunt
# 391                         Murloc Tidehunter (19/18
# 392   Crackling Cyclone (6/3 Divine Shield, Windfury
# 393                         Murloc Tidehunter (21/20
#
#                              minion3  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                Water Droplet (2/2)
# ..                               ...
# 389             Micro Machine (17/14
# 390   Infested Wolf (3/3 Deathrattle
# 391               Sellemental (18/18
# 392                    Lil' Rag (7/7
# 393               Sellemental (20/20
#
#                                              minion4  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ..                                               ...
# 389                          Lightfang Enforcer (2/2
# 390   Crackling Cyclone (4/1 Divine Shield, Windfury
# 391                             Micro Machine (22/18
# 392            Gentle Djinni (4/5 Taunt, Deathrattle
# 393                             Micro Machine (25/20
#
#                                     minion5                       minion6  \
# 0                                      None                          None
# 1                                      None                          None
# 2                                      None                          None
# 3                                      None                          None
# 4                                      None                          None
# ..                                      ...                           ...
# 389                  Brann Bronzebeard (2/4       Brann Bronzebeard (2/4)
# 390                     Micro Machine (1/2)                          None
# 391                  Brann Bronzebeard (2/4        Brann Bronzebeard (2/4
# 392   Gentle Djinni (7/8 Taunt, Deathrattle   Lieutenant Garr (9/44 Taunt
# 393                 Lightfang Enforcer (2/2        Brann Bronzebeard (2/4
#
#                            minion7
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ..                             ...
# 389                           None
# 390                           None
# 391   Deadly Spore (1/1 Poisonous)
# 392      Molten Rock (24/66 Taunt)
# 393        Brann Bronzebeard (2/4)
#
# [394 rows x 7 columns]
