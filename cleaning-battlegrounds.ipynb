# %%
import pandas as pd
from pathlib import Path
from dotenv import load_dotenv
import os
load_dotenv()

## Create .env with folder var, like 'bg-viz/data/'
folder = os.getenv('FOLDER')

df = pd.read_csv(folder + "BGMatchDataGames.csv")
df.dtypes
# Out:
# Date & Time                            object
# Hero                                   object
# Position                                int64
# MMR                                     int64
# Ending Minions                         object
# Minion Types                           object
# Turns taken to reach tavern tier 2      int64
# 3                                       int64
# 4                                       int64
# 5                                     float64
# 6                                     float64
# Ending Turn                             int64
# Game ID                                object
# Player                                 object
# dtype: object

# %%
df
# Out:
#                      Date & Time                   Hero  Position   MMR  \
# 0  Mon, 19 Jul 2021 23:15:02 GMT       Captain Hooktusk         4  6311
# 1  Mon, 19 Jul 2021 23:40:40 GMT  Trade Prince Gallywix         1  6410
# 2  Tue, 20 Jul 2021 00:09:18 GMT           Reno Jackson         6  6383
# 3  Tue, 20 Jul 2021 00:30:53 GMT  Trade Prince Gallywix         5  6384
#
#                                       Ending Minions  \
# 0  Bonker (6/10 Windfury), Tough Tusk (13/12), Ch...
# 1  Bristleback Brute (58/58), Bonker (51/59 Windf...
# 2  Southsea Strongarm (6/7), Salty Looter (6/8), ...
# 3  Deflect-o-Bot (23/22 Divine Shield), Security ...
#
#                                         Minion Types  \
# 0  Available: Quilboar, Elemental, Pirate, Murloc...
# 1  Available: Quilboar, Elemental, Pirate, Murloc...
# 2  Available: Quilboar, Elemental, Pirate, Demon,...
# 3  Available: Quilboar, Elemental, Pirate, Murloc...
#
#    Turns taken to reach tavern tier 2  3  4    5     6  Ending Turn  \
# 0                                   2  4  5  8.0   NaN           11
# 1                                   2  5  6  9.0  13.0           14
# 2                                   2  5  7  NaN   NaN            9
# 3                                   2  4  7  9.0   NaN           12
#
#                                 Game ID          Player
# 0  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# 1  91fb7765-c86e-46b7-b5ae-2dc3409d9e04  Kluckmuck#1143
# 2  adc35959-8c16-4ca4-bed9-25fb8a6869d9  Kluckmuck#1143
# 3  a85b1703-3996-4f74-afae-b4ac5232aafc  Kluckmuck#1143

# %%
pos_avg = df['Position'].mean()
count = df['Game ID'].count()
print("Average Position; " + str(pos_avg))
print("Games Played; " + str(count))
# Out:
# Average Position; 4.0
# Games Played; 4

# %%
df = pd.read_csv(folder + "BGMatchDataBoards.csv")
df.dtypes
# Out:
# dateTime        object
# hero            object
# minions         object
# turn             int64
# isSelf          object
# combatResult    object
# gameId          object
# player          object
# dtype: object

# %%
df
# Out:
#                      Date & Time                   Hero  Position   MMR  \
# 0  Mon, 19 Jul 2021 23:15:02 GMT       Captain Hooktusk         4  6311
# 1  Mon, 19 Jul 2021 23:40:40 GMT  Trade Prince Gallywix         1  6410
# 2  Tue, 20 Jul 2021 00:09:18 GMT           Reno Jackson         6  6383
# 3  Tue, 20 Jul 2021 00:30:53 GMT  Trade Prince Gallywix         5  6384
#
#                                       Ending Minions  \
# 0  Bonker (6/10 Windfury), Tough Tusk (13/12), Ch...
# 1  Bristleback Brute (58/58), Bonker (51/59 Windf...
# 2  Southsea Strongarm (6/7), Salty Looter (6/8), ...
# 3  Deflect-o-Bot (23/22 Divine Shield), Security ...
#
#                                         Minion Types  \
# 0  Available: Quilboar, Elemental, Pirate, Murloc...
# 1  Available: Quilboar, Elemental, Pirate, Murloc...
# 2  Available: Quilboar, Elemental, Pirate, Demon,...
# 3  Available: Quilboar, Elemental, Pirate, Murloc...
#
#    Turns taken to reach tavern tier 2  3  4    5     6  Ending Turn  \
# 0                                   2  4  5  8.0   NaN           11
# 1                                   2  5  6  9.0  13.0           14
# 2                                   2  5  7  NaN   NaN            9
# 3                                   2  4  7  9.0   NaN           12
#
#                                 Game ID          Player
# 0  cc4df18c-e364-4c39-8965-f2c3975d91dd  Kluckmuck#1143
# 1  91fb7765-c86e-46b7-b5ae-2dc3409d9e04  Kluckmuck#1143
# 2  adc35959-8c16-4ca4-bed9-25fb8a6869d9  Kluckmuck#1143
# 3  a85b1703-3996-4f74-afae-b4ac5232aafc  Kluckmuck#1143

# %%
count = len(df.index)
print("Turns Played; " + str(count))
# Out:
# Turns Played; 4
